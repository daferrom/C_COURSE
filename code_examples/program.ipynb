# %%
# I am a comment
print('Hello world')
print('Answer', 42)
print('Name, ' 'Sarah')
print('x', 3.5, 'i' , '10')
# Out:
# Hello world
# Answer 42
# Name, Sarah
# x 3.5 i 10

# %% [markdown]
# # Number Input

# %%
print('Enter US Floor')
usf = int(input())
euf = usf - 1
print('EU Floor', euf)
# Out:
# Enter US Floor
# EU Floor 1

# %% [markdown]
# # String Input

# %%
print('Enter name')
name = input()
print('Hello', name)
# Out:
# Enter name
# Hello Diego Ferro

# %% [markdown]
# ## Line Input

# %%
print('Enter line')
line = input()
print('Line:', line)
# Out:
# Enter line
# Line: hi
